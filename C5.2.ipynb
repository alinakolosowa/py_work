# %%
import random
import math
def printMatrix(c):
    for i in range (len(c)):
        for j in range (len(c)):
            print ( ' {:.2f}'.format(c[i][j]), end = "")
        print ()
c = [[random.randrange(0,5) for x in range(19)] for y in range(19)]
a = [random.uniform(-100,100) for x in range(10)]
b = [random.uniform(-100,100) for x in range(20)]
for i in range(len(b) -1):
    for j in range(len(a)-1):
        c[i][j] = a[j]/(1+abs(b[i]))
printMatrix(c)
# Out:
#  1.49 -1.96 0.59 1.53 0.09 -1.43 -2.08 -1.14 -0.94 1.00 4.00 4.00 4.00 1.00 2.00 1.00 1.00 4.00 2.00
#  1.58 -2.08 0.62 1.63 0.09 -1.52 -2.21 -1.21 -0.99 1.00 1.00 2.00 0.00 3.00 0.00 0.00 4.00 2.00 1.00
#  0.72 -0.95 0.28 0.74 0.04 -0.69 -1.01 -0.55 -0.45 4.00 0.00 4.00 1.00 4.00 2.00 1.00 1.00 0.00 4.00
#  0.60 -0.79 0.24 0.62 0.04 -0.58 -0.84 -0.46 -0.38 2.00 3.00 1.00 3.00 1.00 2.00 2.00 1.00 2.00 2.00
#  1.00 -1.32 0.39 1.03 0.06 -0.96 -1.40 -0.76 -0.63 4.00 2.00 0.00 4.00 3.00 1.00 3.00 1.00 2.00 3.00
#  0.57 -0.75 0.22 0.59 0.03 -0.55 -0.80 -0.44 -0.36 0.00 4.00 0.00 2.00 4.00 3.00 1.00 4.00 1.00 0.00
#  0.90 -1.19 0.35 0.93 0.05 -0.87 -1.26 -0.69 -0.57 0.00 1.00 2.00 1.00 4.00 1.00 2.00 4.00 3.00 3.00
#  0.64 -0.84 0.25 0.66 0.04 -0.62 -0.90 -0.49 -0.40 0.00 3.00 4.00 2.00 2.00 3.00 1.00 0.00 0.00 3.00
#  2.90 -3.81 1.14 2.98 0.17 -2.78 -4.04 -2.21 -1.82 2.00 4.00 3.00 0.00 0.00 4.00 2.00 2.00 2.00 0.00
# ...
